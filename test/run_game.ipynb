# %%
from player import Player
from one_round import OneRound

# %%
class RunGame:
    def __init__(self,player_num,stack,play_num,min_raise,sb_amount):
        self.player_num = player_num
        self.players = []
        for i in range(player_num):
            self.players.append(Player(stack,"player" + str(i),i))
        self.play_num = play_num
        self.current_play_num = 0
        self.min_raise = min_raise
        self.btn_player = 0
        self.sb_amount = sb_amount
        self.result = []

    def start(self):
        for i in range(self.play_num):
            print("round",i+1,":start!!!")
            self.current_play_num += 1
            one_round = OneRound(self.players,self.btn_player,self.sb_amount,self.min_raise)
            one_round.start()

            for i in range(1, self.player_num):
                potential_btn_player = (self.btn_player + i) % self.play_num
                if self.players[potential_btn_player].stack >= 0:
                    self.btn_player = potential_btn_player
                    break
        
        for player in self.players:
            self.result.append(player.stack)
        self.rank_list = sorted(range(len(self.result)), key=lambda i: self.result[i], reverse=True)

        print(self.result)

# %%
game = RunGame(4,10000,3,100,100)

# %%
game.start()
# Out:
# round 1 :start!!!
# 二枚ずつカードを配布
# first round start!!
# [True, True, True, True]
# player3{'player3'} 's hand : {'2s'} {'Kd'}
# current stack {10000} current_bet 0
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'4d'} {'As'}
# current stack {10000} current_bet 0
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'Ks'} {'6h'}
# current stack {9900} current_bet 100
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Qh'} {'5s'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# field card : {'7s'} {'4s'} {'4h'}
# second round start!!(3cards)
# [True, True, True, True]
# player3{'player3'} 's hand : {'2s'} {'Kd'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'4d'} {'As'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'Ks'} {'6h'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Qh'} {'5s'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# field card : {'7s'} {'4s'} {'4h'} {'7h'}
# second round start!!(4cards)
# [True, True, True, True]
# player3{'player3'} 's hand : {'2s'} {'Kd'}
# current stack {9800} current_bet 200
# try again
# {'player3'} 's hand : {'2s'} {'Kd'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'4d'} {'As'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'Ks'} {'6h'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Qh'} {'5s'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# field card : {'7s'} {'4s'} {'4h'} {'7h'} {'3c'}
# second round start!!(5cards)
# [True, True, True, True]
# player3{'player3'} 's hand : {'2s'} {'Kd'}
# current stack {9800} current_bet 200
# try again
# {'player3'} 's hand : {'2s'} {'Kd'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'4d'} {'As'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'Ks'} {'6h'}
# current stack {9800} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Qh'} {'5s'}
# current stack {9800} current_bet 200
# action: f  bet_amount: 200
# judgment start!!
# player0 4d 7s 4s 4h 7h
# player1 Ks 7s 4s 4h 7h
# player2 fold
# player3 Kd 7s 4s 4h 7h
# 0
# round 2 :start!!!
# 二枚ずつカードを配布
# first round start!!
# [True, True, True, True]
# player0{'player0'} 's hand : {'6d'} {'8s'}
# current stack {10600} current_bet 0
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'9h'} {'Ks'}
# current stack {9800} current_bet 0
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Jd'} {'3c'}
# current stack {9700} current_bet 100
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Ah'} {'Jh'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# field card : {'5c'} {'Ac'} {'5d'}
# second round start!!(3cards)
# [True, True, True, True]
# player0{'player0'} 's hand : {'6d'} {'8s'}
# current stack {10400} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'9h'} {'Ks'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Jd'} {'3c'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Ah'} {'Jh'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# field card : {'5c'} {'Ac'} {'5d'} {'2d'}
# second round start!!(4cards)
# [True, True, True, True]
# player0{'player0'} 's hand : {'6d'} {'8s'}
# current stack {10400} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'9h'} {'Ks'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Jd'} {'3c'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Ah'} {'Jh'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# field card : {'5c'} {'Ac'} {'5d'} {'2d'} {'3d'}
# second round start!!(5cards)
# [True, True, True, True]
# player0{'player0'} 's hand : {'6d'} {'8s'}
# current stack {10400} current_bet 200
# action: c  bet_amount: 200
# player1{'player1'} 's hand : {'9h'} {'Ks'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'Jd'} {'3c'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Ah'} {'Jh'}
# current stack {9600} current_bet 200
# action: c  bet_amount: 200
# judgment start!!
# player0 6d 8s 5c Ac 5d
# player1 9h Ks 5c Ac 5d
# player2 3c 5c Ac 5d 3d
# player3 Ah Jh 5c Ac 5d
# 3
# round 3 :start!!!
# 二枚ずつカードを配布
# first round start!!
# [True, True, True, True]
# player1{'player1'} 's hand : {'7d'} {'Ac'}
# current stack {9600} current_bet 0
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'9d'} {'Jd'}
# current stack {9600} current_bet 0
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Kd'} {'6c'}
# current stack {10300} current_bet 100
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'Tc'} {'3c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# field card : {'3s'} {'4s'} {'3h'}
# second round start!!(3cards)
# [True, True, True, True]
# player1{'player1'} 's hand : {'7d'} {'Ac'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'9d'} {'Jd'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Kd'} {'6c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'Tc'} {'3c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# field card : {'3s'} {'4s'} {'3h'} {'4c'}
# second round start!!(4cards)
# [True, True, True, True]
# player1{'player1'} 's hand : {'7d'} {'Ac'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'9d'} {'Jd'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Kd'} {'6c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'Tc'} {'3c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# field card : {'3s'} {'4s'} {'3h'} {'4c'} {'Qh'}
# second round start!!(5cards)
# [True, True, True, True]
# player1{'player1'} 's hand : {'7d'} {'Ac'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player2{'player2'} 's hand : {'9d'} {'Jd'}
# current stack {9400} current_bet 200
# action: c  bet_amount: 200
# player3{'player3'} 's hand : {'Kd'} {'6c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# player0{'player0'} 's hand : {'Tc'} {'3c'}
# current stack {10200} current_bet 200
# action: c  bet_amount: 200
# judgment start!!
# player0 3c 3s 4s 3h 4c
# player1 Ac 3s 4s 3h 4c
# player2 3s 4s 3h 4c Qh
# player3 Kd 3s 4s 3h 4c
# 0

# %%
game.players[1].stack
# Out:
# 9400
